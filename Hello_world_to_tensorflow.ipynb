# %% [markdown]
# <a href="https://colab.research.google.com/github/sarawgiche/Neural-Networks-using-Tensorflow-from-basics-to-advanced/blob/master/Hello_world_to_tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])

# %%
model.compile(optimizer='sgd',loss='mean_squared_error')

# %%
x= np.array([-1.0,0.0,1.0,2.0,3.0,4.0],dtype=float)
y= np.array([-3.0,-1.0,1.0,3.0,5.0,7.0],dtype=float)

# %%
model.fit(x,y,epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 4.5140e-05
# Epoch 2/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 4.4213e-05
# Epoch 3/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.3305e-05
# Epoch 4/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 4.2415e-05
# Epoch 5/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 4.1544e-05
# Epoch 6/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 4.0690e-05
# Epoch 7/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.9854e-05
# Epoch 8/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.9036e-05
# Epoch 9/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8233e-05
# Epoch 10/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.7449e-05
# Epoch 11/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.6679e-05
# Epoch 12/1000
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[18.999987]]
